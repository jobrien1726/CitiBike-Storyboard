# %%
import pandas as pd

# %%
#CSV Files
#jan2019 = "data/201901-citibike-tripdata.csv"
#feb2019 = "data/201902-citibike-tripdata.csv"
#mar2019 = "data/201903-citibike-tripdata.csv"
#apr2019 = "data/201904-citibike-tripdata.csv"
#may2019 = "data/201905-citibike-tripdata.csv"
#jun2019 = "data/201906-citibike-tripdata.csv"
#jul2019 = "data/201907-citibike-tripdata.csv"
#aug2019 = "data/201908-citibike-tripdata.csv"
sept2019 = "data/201909-citibike-tripdata.csv"
oct2019 = "data/201910-citibike-tripdata.csv"
nov2019 = "data/201911-citibike-tripdata.csv"
dec2019 = "data/201912-citibike-tripdata.csv"

# %%
#Read in csv files and view dataframes
# jan2019_df = pd.read_csv("data/201901-citibike-tripdata.csv")
# display(jan2019_df.head())

# feb2019_df = pd.read_csv("data/201902-citibike-tripdata.csv")
# display(feb2019_df.head())

# mar2019_df = pd.read_csv("data/201903-citibike-tripdata.csv")
# display(mar2019_df.head())

# apr2019_df = pd.read_csv("data/201904-citibike-tripdata.csv")
# display(apr2019_df.head())

# may2019_df = pd.read_csv("data/201905-citibike-tripdata.csv")
# display(may2019_df.head())

# jun2019_df = pd.read_csv("data/201906-citibike-tripdata.csv")
# display(jun2019_df.head())

# jul2019_df = pd.read_csv("data/201907-citibike-tripdata.csv")
# display(jul2019_df.head())

# aug2019_df = pd.read_csv("data/201908-citibike-tripdata.csv")
# display(aug2019_df.head())

sept2019_df = pd.read_csv("data/201909-citibike-tripdata.csv")
display(sept2019_df.head())

oct2019_df = pd.read_csv("data/201910-citibike-tripdata.csv")
display(oct2019_df.head())

nov2019_df = pd.read_csv("data/201911-citibike-tripdata.csv")
display(nov2019_df.head())

dec2019_df = pd.read_csv("data/201912-citibike-tripdata.csv")
display(dec2019_df.head())
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           327  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1          1145  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2          1293  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3          1753  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4           613  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
#
#    start station id           start station name  start station latitude  \
# 0              3733           Avenue C & E 18 St               40.730563
# 1              3329         Degraw St & Smith St               40.682915
# 2              3168  Central Park West & W 85 St               40.784727
# 3              3299           E 98 St & Park Ave               40.788130
# 4               486           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# ...

# %%
#Concat all dfs together
dataframes = [sept2019_df, oct2019_df, nov2019_df, dec2019_df]

citibike2019_df = pd.concat(dataframes)
display(citibike2019_df.head())
display(citibike2019_df.tail())
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           327  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1          1145  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2          1293  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3          1753  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4           613  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
#
#    start station id           start station name  start station latitude  \
# 0              3733           Avenue C & E 18 St               40.730563
# 1              3329         Degraw St & Smith St               40.682915
# 2              3168  Central Park West & W 85 St               40.784727
# 3              3299           E 98 St & Park Ave               40.788130
# 4               486           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# ...

# %%
#Output to csv to use in tableau
citibike2019_df.to_csv("output/citibike2019.csv", index=False)
